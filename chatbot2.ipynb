# %%
# !git clone https://github.com/ldulcic/chatbot.git
# Out:
# Cloning into 'chatbot'...
# remote: Enumerating objects: 330, done.
# remote: Total 330 (delta 0), reused 0 (delta 0), pack-reused 330
# Receiving objects: 100% (330/330), 482.07 KiB | 544.00 KiB/s, done.
# Resolving deltas: 100% (190/190), done.

# %%
cd chatbot
# Out:
# /content/chatbot

# %%
# !pip3 install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 8.9MB 8.6MB/s
# ...
#      |████████████████████████████████| 5.3MB 46.2MB/s
# ...
#      |████████████████████████████████| 23.3MB 1.6MB/s
# ...
#      |████████████████████████████████| 519.5MB 32kB/s
# ...
#      |████████████████████████████████| 317kB 44.8MB/s
# ...
#      |████████████████████████████████| 153kB 44.0MB/s
# ...
#      |████████████████████████████████| 184kB 49.3MB/s
# ...
#      |████████████████████████████████| 92kB 11.4MB/s
# ...
#      |████████████████████████████████| 614kB 54.1MB/s
# ...
#      |████████████████████████████████| 1.9MB 42.4MB/s
# ...
#      |████████████████████████████████| 41.4MB 69kB/s
# ...
#      |████████████████████████████████| 450kB 47.4MB/s
# ...
#   Created wheel for tweet-preprocessor: filename=tweet_preprocessor-0.5.0-cp36-none-any.whl size=7947 sha256=b98d56e067ec9cb9266c19f738c02d498af0dc6eb8c7a8d4638e1a26a8971d7a
#   Stored in directory: /root/.cache/pip/wheels/1b/27/cc/49938e98a2470802ebdefae9d2b3f524768e970c1ebbe2dc4a
# ...

# %%
# !python3 -m spacy download en
# Out:
# ...
#      |████████████████████████████████| 37.4MB 839kB/s
# ...
#   Created wheel for en-core-web-sm: filename=en_core_web_sm-2.0.0-cp36-none-any.whl size=37405977 sha256=6a9dcc949a7bcdd00954e073e420c6f521276695a8f2ae86699987bc8877b047
#   Stored in directory: /tmp/pip-ephem-wheel-cache-epvpau7n/wheels/54/7c/d8/f86364af8fbba7258e14adae115f18dd2c91552406edc3fdaa
# Successfully built en-core-web-sm
# ...
#   Found existing installation: en-core-web-sm 2.2.5
#     Uninstalling en-core-web-sm-2.2.5:
#       Successfully uninstalled en-core-web-sm-2.2.5
# ...
#
#     Linking successful
#     /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
#     /usr/local/lib/python3.6/dist-packages/spacy/data/en
#
#     You can now load the model via spacy.load('en')

# %%
# !wget https://www.dropbox.com/s/ibm49gx1gefpqju/pretrained-models.zip
# Out:
# --2020-08-06 12:04:43--  https://www.dropbox.com/s/ibm49gx1gefpqju/pretrained-models.zip
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.1, 2620:100:6031:1::a27d:5101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ibm49gx1gefpqju/pretrained-models.zip [following]
# --2020-08-06 12:04:43--  https://www.dropbox.com/s/raw/ibm49gx1gefpqju/pretrained-models.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucacb6d3097d56d2a6a111c488da.dl.dropboxusercontent.com/cd/0/inline/A89AJusR1u2a7opxB4OTqEMYDpH3TPYjZis3JuhzM1rpz4qkb_Qi6jcI6vxvn2jLHo58FIEa7FWEvru4UAjd-r_Be-SmnaKnnkaM9hlacOJJuQ/file# [following]
# ...

# %%
# !unzip pretrained-models.zip
# !rm pretrained-models.zip
# !sudo chmod +x predict.py
# Out:
# Archive:  pretrained-models.zip
#    creating: pretrained-models/
#    creating: pretrained-models/apple/
#   inflating: pretrained-models/apple/vocab
#   inflating: pretrained-models/apple/seq2seq-39-2.265781-2.457319.pt
#   inflating: pretrained-models/apple/args
#    creating: pretrained-models/delta/
#   inflating: pretrained-models/delta/seq2seq-44-3.276621-3.460837.pt
#   inflating: pretrained-models/delta/vocab
#   inflating: pretrained-models/delta/args
#    creating: pretrained-models/uber/
#   inflating: pretrained-models/uber/seq2seq-58-1.290261-1.604659.pt
#   inflating: pretrained-models/uber/vocab
#   inflating: pretrained-models/uber/args
#    creating: pretrained-models/amazon/
#   inflating: pretrained-models/amazon/seq2seq-10-2.644315-3.045351.pt
#   inflating: pretrained-models/amazon/vocab
#   inflating: pretrained-models/amazon/args
#    creating: pretrained-models/spotify/
#   inflating: pretrained-models/spotify/seq2seq-14-1.861255-2.057882.pt
# ...

# %%
# !./predict.py -cs apple
# Out:
# Args loaded
# Model args loaded.
# Vocab loaded.
# Using CPU for inference
# model loaded
#
#
# Bot: Hi, how can I help you?
# Me: Hi, last ios update made my iphone unstable.
# Bot: we'd like to help. what's happening with your iphone?
# Me: battery is draining fast.
# Bot: we'd like to look into this further. please dm us to continue working on this.< url>
# Me: ok i will dm the details.
# Bot: we've received your dm and will continue working with you there.
# Me: thank you.
# Bot: you're welcome welcome. feel free to reach out to us anytime you need any in the future.
# Me: ok, Bye!
# Bot: we'd like to help. let's take this to dm and we'll elore ways to provide you assistance.< url>
# Me:
