# %%
from zipfile import ZipFile
import shutil
# !git clone https://github.com/zzzDavid/ICDAR-2019-SROIE.git
# Out:
# Cloning into 'ICDAR-2019-SROIE'...
# remote: Enumerating objects: 94, done.
# remote: Counting objects: 100% (94/94), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 2386 (delta 50), reused 65 (delta 22), pack-reused 2292
# Receiving objects: 100% (2386/2386), 278.63 MiB | 12.17 MiB/s, done.
# Resolving deltas: 100% (213/213), done.
# Checking out files: 100% (1980/1980), done.

# %% [markdown]
# # New section

# %% [markdown]
# # New section

# %%
pwd
# Out:
# '/content'

# %%
cd ICDAR-2019-SROIE/
# Out:
# /content/ICDAR-2019-SROIE

# %%
cd task2/
# Out:
# /content/ICDAR-2019-SROIE/task2

# %%
#@title Task 1 CTPN Training and Prediction

# %%
cd task1/
# Out:
# /content/ICDAR-2019-SROIE/task1

# %%
cd CTPN\ Method
# Out:
# /content/ICDAR-2019-SROIE/task1/CTPN Method

# %%
cd utils/bbox
# Out:
# /content/ICDAR-2019-SROIE/task1/CTPN Method/utils/bbox

# %%
# !chmod +x make.sh
# !./make.sh
# Out:
# running install
# running build
# running build_ext
# building 'bbox' extension
# creating build
# creating build/temp.linux-x86_64-3.6
# x86_64-linux-gnu-gcc -pthread -DNDEBUG -g -fwrapv -O2 -Wall -g -fstack-protector-strong -Wformat -Werror=format-security -Wdate-time -D_FORTIFY_SOURCE=2 -fPIC -I/usr/local/lib/python3.6/dist-packages/numpy/core/include -I/usr/include/python3.6m -c bbox.c -o build/temp.linux-x86_64-3.6/bbox.o
# In file included from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarraytypes.h:1832:0,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/ndarrayobject.h:12,
#                  from /usr/local/lib/python3.6/dist-packages/numpy/core/include/numpy/arrayobject.h:4,
#                  from bbox.c:283:
# ...

# %%
#/content/ICDAR-2019-SROIE/task1/CTPN Method/data
#/content/drive/My Drive/ICDAR 2019 Dataset/vgg_16_2016_08_28.tar.gz
#vgg_16.ckpt
# !tar -xvf  '/content/drive/My Drive/ICDAR 2019 Dataset/vgg_16_2016_08_28.tar.gz' -C '/content/ICDAR-2019-SROIE/task1/CTPN Method/data'
# Out:
# vgg_16.ckpt

# %%
#/content/drive/My Drive/ICDAR 2019 Dataset/0325updated.task1train(626p)-20200807T034418Z-001.zip
#/content/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/original
from zipfile import ZipFile
with ZipFile('/content/drive/My Drive/ICDAR 2019 Dataset/0325updated.task1train(626p)-20200807T034418Z-001.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset/original')

# %%
pwd
# Out:
# '/content/ICDAR-2019-SROIE/task1/CTPN Method/utils/bbox'

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE/task1/CTPN Method/utils

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE/task1/CTPN Method

# %%
cd data/dataset/
# Out:
# /content/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset

# %%
# !python3 prepare_dataset.py

# %%
pwd
# Out:
# '/content/ICDAR-2019-SROIE/task1/CTPN Method/data/dataset'

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE/task1/CTPN Method/data

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE/task1/CTPN Method

# %%
from tensorflow.python.compiler.tensorrt import trt_convert as trt

# %%
# !python3 ./main/train.py
# Out:
# 2020-08-07 05:48:47.191888: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# Traceback (most recent call last):
#   File "./main/train.py", line 9, in <module>
#     from tensorflow.contrib import slim
# ModuleNotFoundError: No module named 'tensorflow.contrib'

# %%
#@title Task 1 Pytorch Implementation

# %%
pwd
# Out:
# '/content/ICDAR-2019-SROIE/task1/CTPN Method'

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE/task1

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE

# %%
# !python3 ./task1_revamp/_data.py
# Out:
# torch.Size([3, 448, 224])
# torch.Size([28, 14, 5])
# torch.Size([28, 14, 5, 2])
# torch.Size([28, 14, 5, 2])
# torch.Size([28, 14, 5])
# torch.Size([28, 14, 5])

# %%
# !python3 ./task1_revamp/_util.py
# Out:
# tensor([[ 0.0823,  0.8664, -0.5007],
#         [-0.3793, -1.4934, -0.1823]])

# %%
# !python3 ./task1_revamp/_model.py
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# 100% 528M/528M [00:05<00:00, 108MB/s]
# torch.Size([1, 28, 14, 10, 2])
# torch.Size([1, 28, 14, 10, 2])
# torch.Size([1, 28, 14, 10])

# %%
# !python3 ./task1_revamp/_viz.py

# %%
import torch
#torch.cuda.memory_summary(device=None, abbreviated=False)

# %%
# !python3 ./task1_revamp/train.py
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16_bn-6c64b313.pth" to /root/.cache/torch/hub/checkpoints/vgg16_bn-6c64b313.pth
# 100% 528M/528M [00:07<00:00, 78.3MB/s]
# device = cuda:0
# train_size = 560
# valid_size = 66
# Epoch 1.1
# 	Loss: 2.028416156768799 (0.6979567408561707, 0.1397528499364853, 1.1907066106796265)
# Traceback (most recent call last):
#   File "./task1_revamp/train.py", line 108, in <module>
#     train(model, dataset, device, batch_size=8)
#   File "./task1_revamp/train.py", line 60, in train
#     loss.backward()
#   File "/usr/local/lib/python3.6/dist-packages/torch/tensor.py", line 185, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph)
#   File "/usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py", line 127, in backward
#     allow_unreachable=True)  # allow_unreachable flag
# RuntimeError: element 0 of tensors does not require grad and does not have a grad_fn

# %%
#@title Training Task 2

# %%
pwd
# Out:
# '/content/ICDAR-2019-SROIE/task2'

# %%
cd task2/
# Out:
# /content/ICDAR-2019-SROIE/task2

# %%
shutil.rmtree("/content/ICDAR-2019-SROIE/task2/data_train")

# %%
shutil.rmtree("/content/ICDAR-2019-SROIE/task2/data_valid")

# %%
#/content/drive/My Drive/ICDAR 2019 Dataset/data_train.zip
#/content/drive/My Drive/ICDAR 2019 Dataset/data_valid.zip
with ZipFile('/content/drive/My Drive/ICDAR 2019 Dataset/data_train.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/ICDAR-2019-SROIE/task2')

# %%
with ZipFile('/content/drive/My Drive/ICDAR 2019 Dataset/data_valid.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/ICDAR-2019-SROIE/task2')

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE

# %%
cd task2/
# Out:
# /content/ICDAR-2019-SROIE/task2

# %%
#txn.put(str(k).encode(), str(v).encode())
# !python3 ./create_dataset.py
# Out:
# Written 1000 / 27037
# Written 2000 / 27037
# Written 3000 / 27037
# Written 4000 / 27037
# Written 5000 / 27037
# Written 6000 / 27037
# Written 7000 / 27037
# Written 8000 / 27037
# Written 9000 / 27037
# Written 10000 / 27037
# Written 11000 / 27037
# Written 12000 / 27037
# Written 13000 / 27037
# Written 14000 / 27037
# Written 15000 / 27037
# Written 16000 / 27037
# Written 17000 / 27037
# Written 18000 / 27037
# Written 19000 / 27037
# Written 20000 / 27037
# Written 21000 / 27037
# Written 22000 / 27037
# Written 23000 / 27037
# Written 24000 / 27037
# Written 25000 / 27037
# Written 26000 / 27037
# Written 27000 / 27037
# Created dataset with 27037 samples
# Written 1000 / 6491
# Written 2000 / 6491
# Written 3000 / 6491
# Written 4000 / 6491
# Written 5000 / 6491
# Written 6000 / 6491
# Created dataset with 6491 samples

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE/task2/warp-ctc

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE/task2

# %%
# !pip install pytorch torchvision cudatoolkit==9.2
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/ee/67/f403d4ae6e9cd74b546ee88cccdb29b8415a9c1b3d80aebeb20c9ea91d96/pytorch-1.0.2.tar.gz
# ...
# ERROR: Could not find a version that satisfies the requirement cudatoolkit==9.2 (from versions: none)
# ERROR: No matching distribution found for cudatoolkit==9.2

# %%
shutil.move("/content/ICDAR-2019-SROIE/task2/warp-ctc/pytorch_binding/warpctc_pytorch", "/content/ICDAR-2019-SROIE/task2")
# Out:
# '/content/ICDAR-2019-SROIE/task2/warpctc_pytorch'

# %%
# !python3 train.py --adadelta --trainRoot {train_path} --valRoot {val_path} --cuda
# Out:
# Traceback (most recent call last):
#   File "train.py", line 9, in <module>
#     from warpctc_pytorch import CTCLoss
#   File "/content/ICDAR-2019-SROIE/task2/warpctc_pytorch/__init__.py", line 6, in <module>
#     from ._warp_ctc import *
# ModuleNotFoundError: No module named 'warpctc_pytorch._warp_ctc'

# %%
# !pip install pytorch pytorch-nightly torchvision cudatoolkit==10.0
# !pip install torchvision==0.2.2
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/ee/67/f403d4ae6e9cd74b546ee88cccdb29b8415a9c1b3d80aebeb20c9ea91d96/pytorch-1.0.2.tar.gz
# ERROR: Could not find a version that satisfies the requirement pytorch-nightly (from versions: none)
# ERROR: No matching distribution found for pytorch-nightly
# ...

# %%
# !git clone https://github.com/SeanNaren/warp-ctc.git
# Out:
# Cloning into 'warp-ctc'...
# remote: Enumerating objects: 14, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 805 (delta 3), reused 6 (delta 2), pack-reused 791
# Receiving objects: 100% (805/805), 387.90 KiB | 549.00 KiB/s, done.
# Resolving deltas: 100% (404/404), done.

# %%
cd warp-ctc
# Out:
# /content/ICDAR-2019-SROIE/task2/warp-ctc

# %%
mkdir build

# %%
cd build
# Out:
# /content/ICDAR-2019-SROIE/task2/warp-ctc/build

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE/task2/warp-ctc

# %%
cd pytorch_binding
# Out:
# /content/ICDAR-2019-SROIE/task2/warp-ctc/pytorch_binding

# %%
# !python3 setup.py install
# Out:
# Could not find libwarpctc.so in ../build.
# Build warp-ctc and set WARP_CTC_PATH to the location of libwarpctc.so (default is '../build')

# %%
cd ../build
# Out:
# /content/ICDAR-2019-SROIE/task2/warp-ctc/build

# %%
cp libwarpctc.dylib /content/ICDAR-2019-SROIE/task2/warp-ctc/build
# Out:
# cp: cannot stat 'libwarpctc.dylib': No such file or directory

# %%
# !pip install warpctc-pytorch10-cuda92
#from torch_baidu_ctc import ctc_loss, CTCLoss
# Out:
# ...
#      |████████████████████████████████| 2.4MB 10.9MB/s
# ...

# %%
# !pip install torch-baidu-ctc
# Out:
# ...
#      |████████████████████████████████| 2.7MB 4.6MB/s
# ...
#      |████████████████████████████████| 296kB 40.9MB/s
# ...

# %%
! CC=gcc-4.9 CXX=g++-4.9 pip install torch-baidu-ctc

# %%
import torch
print(torch.__version__)
torch.cuda.is_available()
# Out:
# 1.6.0+cu101
# True

# %%
#@title Prediction Part of Task 2

# %%
pwd
# Out:
# '/content/ICDAR-2019-SROIE/task2'

# %%
shutil.rmtree("/content/ICDAR-2019-SROIE/task2/boundingbox")
shutil.rmtree("/content/ICDAR-2019-SROIE/task2/data_test")
shutil.rmtree("/content/ICDAR-2019-SROIE/task2/expr")

# %%
#/content/drive/My Drive/ICDAR 2019 Dataset/expr.zip
with ZipFile('/content/drive/My Drive/ICDAR 2019 Dataset/expr.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/ICDAR-2019-SROIE/task2')

# %%
#/content/drive/My Drive/ICDAR 2019 Dataset/boundingbox.zip
with ZipFile('/content/drive/My Drive/ICDAR 2019 Dataset/boundingbox.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/ICDAR-2019-SROIE/task2')

# %%
#/content/drive/My Drive/ICDAR 2019 Dataset/data_test.zip
with ZipFile('/content/drive/My Drive/ICDAR 2019 Dataset/data_test.zip', 'r') as zipObj:
   # Extract all the contents of zip file in different directory
   zipObj.extractall('/content/ICDAR-2019-SROIE/task2')

# %%
# !python3 utils.py

# %%
# !python3 dataset.py

# %%
mkdir task2_result

# %%
# !python3 main.py
# Out:
# Streaming output truncated to the last 5000 lines.
# -----1-------  --p-------c------------------------- => 1 pc
# --2--5-0-----   0-.0--0---------  -2--5-0---s-r---- => 250 0.00 250sr
# -----8--6--0--0--0----k--l---u--a--n---g----------- => 86000kluang
# --3--3-0----    0-.-0-0--------    3--3-0-  s-r---- => 330 0.00 330 sr
# --d--ccuumm-entt n-o. :  k-l-g-0-201-1-3-0222------ => dcument no. : klg02011302
# --------k-----l-----g------2----------------------" => klg2"
# --------d-------ee----ss----cc--------------------- => desc
# ---6---------  pp-------c-------------------------- => 6 pc
# ------1-----------pp------c------------------------ => 1pc
# ----6--0-- &--  6--2---  j-a-lla-nn- -c--kk-u------ => 60 & 62 jalan cku
# --1--6-0-----   0-.0-0---------    1--6-0- s--r---- => 160 0.00 160 sr
# -------11------- --p-------c----------------------- => 1 pc
# -----3-----4-----6----------5-----1------11-------- => 346511
# ------1-------  --p-------c------------------------ => 1 pc
# ...

# %%
#!pip install models
#!sudo easy_install models
#!pip install doqu
#import models
# !git clone https://github.com/meijieru/crnn.pytorch.git
# Out:
# Cloning into 'crnn.pytorch'...
# remote: Enumerating objects: 1, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 82 (delta 0), reused 0 (delta 0), pack-reused 81
# Unpacking objects: 100% (82/82), done.

# %%
shutil.move("/content/ICDAR-2019-SROIE/task2/crnn.pytorch/models", "/content/ICDAR-2019-SROIE/task2")
# Out:
# '/content/ICDAR-2019-SROIE/task2/models'

# %%
import models

# %%
#!pip install keras_ocr
#import keras_ocr

# %%
mkdir for_task3

# %%
#@title Task 3 using Preloaded Data

# %%
cd ..
# Out:
# /content/ICDAR-2019-SROIE

# %%
cd task3/
# Out:
# /content/ICDAR-2019-SROIE/task3

# %%
# !pip install colorama

# %%
mkdir ./src/results

# %%
# change the storage directory from results/ to src/results/ both in train.py and test.py files 
! python3 ./src/train.py
# Out:
# #0001 | Loss: 1.6049
# #0002 | Loss: 1.5217
# #0003 | Loss: 1.4472
# #0004 | Loss: 1.3284
# #0005 | Loss: 1.2473
# #0006 | Loss: 1.2848
# #0007 | Loss: 1.1530
# #0008 | Loss: 1.1770
# #0009 | Loss: 1.1871
# #0010 | Loss: 1.2255
# #0011 | Loss: 1.2332
# #0012 | Loss: 1.1934
# #0013 | Loss: 1.1777
# #0014 | Loss: 1.1632
# #0015 | Loss: 1.0027
# #0016 | Loss: 1.7162
# #0017 | Loss: 1.0690
# #0018 | Loss: 1.0794
# #0019 | Loss: 0.8820
# #0020 | Loss: 0.9468
# #0021 | Loss: 0.8725
# #0022 | Loss: 0.8801
# #0023 | Loss: 0.8419
# #0024 | Loss: 0.8921
# #0025 | Loss: 0.8526
# #0026 | Loss: 0.7697
# #0027 | Loss: 0.8549
# #0028 | Loss: 0.7104
# #0029 | Loss: 0.5767
# #0030 | Loss: 0.6892
# #0031 | Loss: 0.8130
# #0032 | Loss: 0.7250
# #0033 | Loss: 0.6528
# #0034 | Loss: 1.0729
# #0035 | Loss: 0.6826
# #0036 | Loss: 0.6657
# #0037 | Loss: 0.5783
# #0038 | Loss: 0.7083
# #0039 | Loss: 0.6079
# #0040 | Loss: 0.5510
# #0041 | Loss: 0.5784
# #0042 | Loss: 0.6212
# #0043 | Loss: 0.5253
# ...

# %%
! python3 ./src/my_classes.py

# %%
! python3 ./src/my_data.py
# Out:
# Traceback (most recent call last):
#   File "./src/my_data.py", line 211, in <module>
#     create_test_data()
#   File "./src/my_data.py", line 126, in create_test_data
#     for f in os.scandir("tmp/task3-test(347p)")
# FileNotFoundError: [Errno 2] No such file or directory: 'tmp/task3-test(347p)'

# %%
! python ./src/my_utils.py
# Out:
# 0.5981620718462823

# %%
! python3 ./src/test.py
# Out:
# X00016469670
# X00016469671
# X51005200931
# X51005230605
# X51005230616
# X51005230621
# X51005230648
# X51005230657
# X51005230659
# X51005268275
# X51005268408
# X51005288570
# X51005301666
# X51005337867
# X51005337877
# X51005361906
# X51005361908
# X51005361912
# X51005361923
# X51005365187
# X51005433518
# X51005433543
# X51005433548
# X51005433556
# X51005442322
# X51005442334
# X51005442343
# X51005442366
# X51005442375
# X51005442382
# X51005442388
# X51005444040
# X51005444041
# X51005444044
# X51005444046
# X51005447841
# X51005447842
# X51005447844
# X51005447851
# X51005447859
# X51005568855
# X51005568866
# X51005568885
# X51005568887
# X51005568889
# X51005568890
# X51005568892
# X51005568894
# X51005568895
# X51005577191
# X51005582745
# X51005587261
# X51005605287
# X51005605295
# X51005605332
# X51005621482
# X51005663274
# X51005663300
# X51005663307
# X51005663309
# X51005663310
# X51005663323
# X51005675099
# X51005675103
# X51005675104
# X51005675914
# ...

# %%
#import json
#data = {}
#with open('src/results/X00016469670.json', "w") as write_file:
#    json.dump(data, write_file)
