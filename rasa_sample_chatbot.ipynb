# %%
# !pip install rasa
# Out:
# ...
#      |████████████████████████████████| 512kB 2.7MB/s
# ...
#      |████████████████████████████████| 51kB 5.7MB/s
# ...
#      |████████████████████████████████| 1.2MB 9.6MB/s
# ...
#      |████████████████████████████████| 419kB 17.3MB/s
# ...
#      |████████████████████████████████| 512kB 18.3MB/s
# ...
#      |████████████████████████████████| 153kB 24.6MB/s
# ...
#      |████████████████████████████████| 5.1MB 21.1MB/s
# ...
#      |████████████████████████████████| 2.9MB 49.5MB/s
# ...
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ProtocolError('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))': /simple/python-socketio/
# ...

# %%
# !python -m spacy download en
# Out:
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !rasa init
# Out:
# Welcome to Rasa! 🤖
#
# To get started quickly, an initial project will be created.
# If you need some help, check out the documentation at https://rasa.com/docs/rasa.
# Now let's start! 👇🏽
#
# t
# WARNING: your terminal doesn't support cursor position requests (CPR).
# t
# t
#
# WARNING: your terminal doesn't support cursor position requests (CPR).
#
# Created project directory at '/content/.ij'.
# Finished creating project structure.
#
# Training an initial model...
# Training Core model...
# 2020-08-19 10:29:29 INFO     root  - Generating grammar tables from /usr/lib/python3.6/lib2to3/Grammar.txt
# 2020-08-19 10:29:29 INFO     root  - Generating grammar tables from /usr/lib/python3.6/lib2to3/PatternGrammar.txt
# Processed Story Blocks: 100% 5/5 [00:00<00:00, 3286.56it/s, # trackers=1]
# Processed Story Blocks: 100% 5/5 [00:00<00:00, 1451.82it/s, # trackers=5]
# Processed Story Blocks: 100% 5/5 [00:00<00:00, 359.43it/s, # trackers=20]
# ...

# %%
from rasa.nlu.model import Interpreter

# %%
ls
# Out:
# sample_data/

# %%
cd sample_data

# %%
ls
# Out:
# sample_data/
